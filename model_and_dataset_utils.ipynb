# %% [markdown]
# # Finetuning with mlx-lm
# ### notebook to inspect, build a lora config yaml, and convert datasets

# %%
# Set defaults
user = ""
root_path = "/Users/{user}/mlx"
model_path = f"{root_path}/Storage/my_model"
data_path = f"{root_path}/traindata"

# model format, ie: model-00001-of-00005.safetensors
model_format = "model-00001-of-00005.safetensors"

model = model_path + "/" + model_format

# %% [markdown]
# ### Inspection

# %%
import json
import mlx.core as mx


def prod(shape):
    result = 1
    for dim in shape:
        result *= dim
    return result


def inspect_model(model_files):
    total_layers = 0
    total_params = 0

    for model_file in model_files:
        with open(model_file, "rb") as f:
            header_len = int.from_bytes(f.read(8), "little")
            header = json.loads(f.read(header_len))

            num_layers = len([k for k in header if k.startswith("layers")])
            num_params = sum(
                prod(mx.array(v["shape"])) for v in header.values() if "shape" in v
            )

            total_layers += num_layers
            total_params += num_params

            # print(f"File: {model_file}")
            print("Header information:")
            for k, v in header.items():
                print(f"{k}: {v}")
            print()

    print("Total across all files:")
    print(f"Total layers: {total_layers}")
    print(f"Total parameters: {total_params}")


# Usage example
model_files = [
    f"{model_path}/model-00001-of-00005.safetensors",
    f"{model_path}/model-00002-of-00005.safetensors",
    f"{model_path}/model-00003-of-00005.safetensors",
    f"{model_path}/model-00004-of-00005.safetensors",
    f"{model_path}/model-00005-of-00005.safetensors",
]

inspect_model(model_files)
# Out:
# Header information:
# __metadata__: {'format': 'mlx'}
# model.embed_tokens.weight: {'data_offsets': [4815310848, 5208526848], 'dtype': 'F16', 'shape': [32000, 6144]}
# model.layers.0.input_layernorm.weight: {'data_offsets': [4271456256, 4271468544], 'dtype': 'F16', 'shape': [6144]}
# model.layers.0.mlp.down_proj.biases: {'data_offsets': [4269772800, 4271345664], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.0.mlp.down_proj.scales: {'data_offsets': [4492357632, 4493930496], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.0.mlp.down_proj.weight: {'data_offsets': [4391694336, 4492357632], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.0.mlp.gate_proj.biases: {'data_offsets': [2494402560, 2495975424], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.0.mlp.gate_proj.scales: {'data_offsets': [4008370176, 4009943040], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.0.mlp.gate_proj.weight: {'data_offsets': [3267244032, 3367907328], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.0.mlp.up_proj.biases: {'data_offsets': [3514281984, 3515854848], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.0.mlp.up_proj.scales: {'data_offsets': [4313935872, 4315508736], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.0.mlp.up_proj.weight: {'data_offsets': [3795935232, 3896598528], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.0.post_attention_layernorm.weight: {'data_offsets': [5309878272, 5309890560], 'dtype': 'F16', 'shape': [6144]}
# model.layers.0.self_attn.k_proj.biases: {'data_offsets': [3161960448, 3162058752], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.0.self_attn.k_proj.scales: {'data_offsets': [4808921088, 4809019392], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.0.self_attn.k_proj.weight: {'data_offsets': [2900631552, 2906923008], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.0.self_attn.o_proj.biases: {'data_offsets': [4272156672, 4272746496], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.0.self_attn.o_proj.scales: {'data_offsets': [3115855872, 3116445696], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.0.self_attn.o_proj.weight: {'data_offsets': [3515953152, 3553701888], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.0.self_attn.q_proj.biases: {'data_offsets': [5208526848, 5209116672], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.0.self_attn.q_proj.scales: {'data_offsets': [2473365504, 2473955328], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.0.self_attn.q_proj.weight: {'data_offsets': [3600015360, 3637764096], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.0.self_attn.v_proj.biases: {'data_offsets': [4353257472, 4353355776], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.0.self_attn.v_proj.scales: {'data_offsets': [3267145728, 3267244032], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.0.self_attn.v_proj.weight: {'data_offsets': [3750322176, 3756613632], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.1.input_layernorm.weight: {'data_offsets': [4271345664, 4271357952], 'dtype': 'F16', 'shape': [6144]}
# model.layers.1.mlp.down_proj.biases: {'data_offsets': [2498727936, 2500300800], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.1.mlp.down_proj.scales: {'data_offsets': [4126052352, 4127625216], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.1.mlp.down_proj.weight: {'data_offsets': [5209214976, 5309878272], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.1.mlp.gate_proj.biases: {'data_offsets': [3748749312, 3750322176], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.1.mlp.gate_proj.scales: {'data_offsets': [4127625216, 4129198080], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.1.mlp.gate_proj.weight: {'data_offsets': [3902889984, 4003553280], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.1.mlp.up_proj.biases: {'data_offsets': [5309890560, 5311463424], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.1.mlp.up_proj.scales: {'data_offsets': [2288455680, 2290028544], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.1.mlp.up_proj.weight: {'data_offsets': [2294943744, 2395607040], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.1.post_attention_layernorm.weight: {'data_offsets': [1924792320, 1924804608], 'dtype': 'F16', 'shape': [6144]}
# model.layers.1.self_attn.k_proj.biases: {'data_offsets': [4272058368, 4272156672], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.1.self_attn.k_proj.scales: {'data_offsets': [4272844800, 4272943104], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.1.self_attn.k_proj.weight: {'data_offsets': [4009943040, 4016234496], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.1.self_attn.o_proj.biases: {'data_offsets': [4016234496, 4016824320], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.1.self_attn.o_proj.scales: {'data_offsets': [2909110272, 2909700096], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.1.self_attn.o_proj.weight: {'data_offsets': [4274515968, 4312264704], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.1.self_attn.q_proj.biases: {'data_offsets': [3644055552, 3644645376], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.1.self_attn.q_proj.scales: {'data_offsets': [2181672960, 2182262784], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.1.self_attn.q_proj.weight: {'data_offsets': [4353355776, 4391104512], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.1.self_attn.v_proj.biases: {'data_offsets': [4271357952, 4271456256], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.1.self_attn.v_proj.scales: {'data_offsets': [2286194688, 2286292992], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.1.self_attn.v_proj.weight: {'data_offsets': [4018987008, 4025278464], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.10.input_layernorm.weight: {'data_offsets': [237318144, 237330432], 'dtype': 'F16', 'shape': [6144]}
# model.layers.10.mlp.down_proj.biases: {'data_offsets': [337993728, 339566592], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.10.mlp.down_proj.scales: {'data_offsets': [339566592, 341139456], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.10.mlp.down_proj.weight: {'data_offsets': [4025376768, 4126040064], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.10.mlp.gate_proj.biases: {'data_offsets': [3112599552, 3114172416], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.10.mlp.gate_proj.scales: {'data_offsets': [527548416, 529121280], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.10.mlp.gate_proj.weight: {'data_offsets': [341139456, 441802752], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.10.mlp.up_proj.biases: {'data_offsets': [1187684352, 1189257216], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.10.mlp.up_proj.scales: {'data_offsets': [1597231104, 1598803968], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.10.mlp.up_proj.weight: {'data_offsets': [237330432, 337993728], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers
 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.3.mlp.up_proj.weight: {'data_offsets': [2026254336, 2126917632], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.3.post_attention_layernorm.weight: {'data_offsets': [4808220672, 4808232960], 'dtype': 'F16', 'shape': [6144]}
# model.layers.3.self_attn.k_proj.biases: {'data_offsets': [3116445696, 3116544000], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.3.self_attn.k_proj.scales: {'data_offsets': [3122835456, 3122933760], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.3.self_attn.k_proj.weight: {'data_offsets': [4809019392, 4815310848], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.3.self_attn.o_proj.biases: {'data_offsets': [1642844160, 1643433984], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.3.self_attn.o_proj.scales: {'data_offsets': [4494041088, 4494630912], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.3.self_attn.o_proj.weight: {'data_offsets': [3559993344, 3597742080], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.3.self_attn.q_proj.biases: {'data_offsets': [3123032064, 3123621888], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.3.self_attn.q_proj.scales: {'data_offsets': [3123621888, 3124211712], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.3.self_attn.q_proj.weight: {'data_offsets': [3124211712, 3161960448], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.3.self_attn.v_proj.biases: {'data_offsets': [4025278464, 4025376768], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.3.self_attn.v_proj.scales: {'data_offsets': [3115745280, 3115843584], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.3.self_attn.v_proj.weight: {'data_offsets': [3896598528, 3902889984], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.4.input_layernorm.weight: {'data_offsets': [2812342272, 2812354560], 'dtype': 'F16', 'shape': [6144]}
# model.layers.4.mlp.down_proj.biases: {'data_offsets': [1440141312, 1441714176], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.4.mlp.down_proj.scales: {'data_offsets': [1643433984, 1645006848], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.4.mlp.down_proj.weight: {'data_offsets': [2506518528, 2607181824], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.4.mlp.gate_proj.biases: {'data_offsets': [2808508416, 2810081280], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.4.mlp.gate_proj.scales: {'data_offsets': [2810179584, 2811752448], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.4.mlp.gate_proj.weight: {'data_offsets': [4706967552, 4807630848], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.4.mlp.up_proj.biases: {'data_offsets': [2500411392, 2501984256], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.4.mlp.up_proj.scales: {'data_offsets': [2504245248, 2505818112], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.4.mlp.up_proj.weight: {'data_offsets': [2607181824, 2707845120], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.4.post_attention_layernorm.weight: {'data_offsets': [2500300800, 2500313088], 'dtype': 'F16', 'shape': [6144]}
# model.layers.4.self_attn.k_proj.biases: {'data_offsets': [3515854848, 3515953152], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.4.self_attn.k_proj.scales: {'data_offsets': [2856493056, 2856591360], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.4.self_attn.k_proj.weight: {'data_offsets': [2894340096, 2900631552], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.4.self_attn.o_proj.biases: {'data_offsets': [2811752448, 2812342272], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.4.self_attn.o_proj.scales: {'data_offsets': [4271468544, 4272058368], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.4.self_attn.o_proj.weight: {'data_offsets': [4232024064, 4269772800], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.4.self_attn.q_proj.biases: {'data_offsets': [2906923008, 2907512832], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.4.self_attn.q_proj.scales: {'data_offsets': [3745406976, 3745996800], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.4.self_attn.q_proj.weight: {'data_offsets': [1605095424, 1642844160], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.4.self_attn.v_proj.biases: {'data_offsets': [4312264704, 4312363008], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.4.self_attn.v_proj.scales: {'data_offsets': [2850103296, 2850201600], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.4.self_attn.v_proj.weight: {'data_offsets': [2850201600, 2856493056], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.5.input_layernorm.weight: {'data_offsets': [2182275072, 2182287360], 'dtype': 'F16', 'shape': [6144]}
# model.layers.5.mlp.down_proj.biases: {'data_offsets': [2497155072, 2498727936], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.5.mlp.down_proj.scales: {'data_offsets': [3114172416, 3115745280], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.5.mlp.down_proj.weight: {'data_offsets': [2183860224, 2284523520], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.5.mlp.gate_proj.biases: {'data_offsets': [2284621824, 2286194688], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.5.mlp.gate_proj.scales: {'data_offsets': [2290028544, 2291601408], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.5.mlp.gate_proj.weight: {'data_offsets': [3413618688, 3514281984], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.5.mlp.up_proj.biases: {'data_offsets': [2486538240, 2488111104], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.5.mlp.up_proj.scales: {'data_offsets': [2182287360, 2183860224], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.5.mlp.up_proj.weight: {'data_offsets': [4131360768, 4232024064], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.5.post_attention_layernorm.weight: {'data_offsets': [3115843584, 3115855872], 'dtype': 'F16', 'shape': [6144]}
# model.layers.5.self_attn.k_proj.biases: {'data_offsets': [2505830400, 2505928704], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.5.self_attn.k_proj.scales: {'data_offsets': [2810081280, 2810179584], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.5.self_attn.k_proj.weight: {'data_offsets': [2488111104, 2494402560], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.5.self_attn.o_proj.biases: {'data_offsets': [2291601408, 2292191232], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.5.self_attn.o_proj.scales: {'data_offsets': [2292781056, 2293370880], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.5.self_attn.o_proj.weight: {'data_offsets': [2395607040, 2433355776], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.5.self_attn.q_proj.biases: {'data_offsets': [2495975424, 2496565248], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.5.self_attn.q_proj.scales: {'data_offsets': [2496565248, 2497155072], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.5.self_attn.q_proj.weight: {'data_offsets': [1884192768, 1921941504], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.5.self_attn.v_proj.biases: {'data_offsets': [2471694336, 2471792640], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.5.self_attn.v_proj.scales: {'data_offsets': [1846333440, 1846431744], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.5.self_attn.v_proj.weight: {'data_offsets': [2480246784, 2486538240], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.6.input_layernorm.weight: {'data_offsets': [2907525120, 2907537408], 'dtype': 'F16', 'shape': [6144]}
# model.layers.6.mlp.down_proj.biases: {'data_offsets': [4016824320, 4018397184], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.6.mlp.down_proj.scales: {'data_offsets': [1603522560, 1605095424], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.6.mlp.down_proj.weight: {'data_offsets': [4504068096, 4604731392], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.6.mlp.gate_proj.biases: {'data_offsets': [1598803968, 1600376832], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.6.mlp.gate_proj.scales: {'data_offsets': [3597852672, 3599425536], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.6.mlp.gate_proj.weight: {'data_offsets': [1645006848, 1745670144], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.6.mlp.up_proj.biases: {'data_offsets': [4129787904, 4131360768], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.6.mlp.up_proj.scales: {'data_offsets': [1600376832, 1601949696], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.6.mlp.up_proj.weight: {'data_offsets': [4604731392, 4705394688], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.6.post_attention_layernorm.weight: {'data_offsets': [3597840384, 3597852672], 'dtype': 'F16', 'shape': [6144]}
# model.layers.6.self_attn.k_proj.biases: {'data_offsets': [2026156032, 2026254336], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.6.self_attn.k_proj.scales: {'data_offsets': [2133209088, 2133307392], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.6.self_attn.k_proj.weight: {'data_offsets': [2133897216, 2140188672], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.6.self_attn.o_proj.biases: {'data_offsets': [1921941504, 1922531328], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.6.self_attn.o_proj.scales: {'data_offsets': [1924104192, 1924694016], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.6.self_attn.o_proj.weight: {'data_offsets': [2856591360, 2894340096], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.6.self_attn.q_proj.biases: {'data_offsets': [3599425536, 3600015360], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.6.self_attn.q_proj.scales: {'data_offsets': [2140188672, 2140778496], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.6.self_attn.q_proj.weight: {'data_offsets': [2142351360, 2180100096], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.6.self_attn.v_proj.biases: {'data_offsets': [1924694016, 1924792320], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.6.self_attn.v_proj.scales: {'data_offsets': [2025467904, 2025566208], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.6.self_attn.v_proj.weight: {'data_offsets': [1441714176, 1448005632], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.7.input_layernorm.weight: {'data_offsets': [1337892864, 1337905152], 'dtype': 'F16', 'shape': [6144]}
# model.layers.7.mlp.down_proj.biases: {'data_offsets': [4006797312, 4008370176], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.7.mlp.down_proj.scales: {'data_offsets': [2471792640, 2473365504], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.7.mlp.down_proj.weight: {'data_offsets': [1339478016, 1440141312], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.7.mlp.gate_proj.biases: {'data_offsets': [1448005632, 1449578496], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.7.mlp.gate_proj.scales: {'data_offsets': [1449578496, 1451151360], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.7.mlp.gate_proj.weight: {'data_offsets': [1451151360, 1551814656], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.7.mlp.up_proj.biases: {'data_offsets': [1337905152, 1339478016], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.7.mlp.up_proj.scales: {'data_offsets': [4502495232, 4504068096], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.7.mlp.up_proj.weight: {'data_offsets': [1924804608, 2025467904], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.7.post_attention_layernorm.weight: {'data_offsets': [2182262784, 2182275072], 'dtype': 'F16', 'shape': [6144]}
# model.layers.7.self_attn.k_proj.biases: {'data_offsets': [1596542976, 1596641280], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.7.self_attn.k_proj.scales: {'data_offsets': [5209116672, 5209214976], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.7.self_attn.k_proj.weight: {'data_offsets': [2126917632, 2133209088], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.7.self_attn.o_proj.biases: {'data_offsets': [1551814656, 1552404480], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.7.self_attn.o_proj.scales: {'data_offsets': [2503655424, 2504245248], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.7.self_attn.o_proj.weight: {'data_offsets': [1552404480, 1590153216], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.7.self_attn.q_proj.biases: {'data_offsets': [3745996800, 3746586624], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.7.self_attn.q_proj.scales: {'data_offsets': [1596641280, 1597231104], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.7.self_attn.q_proj.weight: {'data_offsets': [1846431744, 1884180480], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.7.self_attn.v_proj.biases: {'data_offsets': [4493930496, 4494028800], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.7.self_attn.v_proj.scales: {'data_offsets': [1590153216, 1590251520], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.7.self_attn.v_proj.weight: {'data_offsets': [3553701888, 3559993344], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.8.input_layernorm.weight: {'data_offsets': [982609920, 982622208], 'dtype': 'F16', 'shape': [6144]}
# model.layers.8.mlp.down_proj.biases: {'data_offsets': [2907537408, 2909110272], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.8.mlp.down_proj.scales: {'data_offsets': [2180100096, 2181672960], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.8.mlp.down_proj.weight: {'data_offsets': [1084858368, 1185521664], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.8.mlp.gate_proj.biases: {'data_offsets': [1186111488, 1187684352], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.8.mlp.gate_proj.scales: {'data_offsets': [1189257216, 1190830080], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.8.mlp.gate_proj.weight: {'data_offsets': [1190830080, 1291493376], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.8.mlp.up_proj.biases: {'data_offsets': [2502082560, 2503655424], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.8.mlp.up_proj.scales: {'data_offsets': [4500922368, 4502495232], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.8.mlp.up_proj.weight: {'data_offsets': [982622208, 1083285504], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.8.post_attention_layernorm.weight: {'data_offsets': [982597632, 982609920], 'dtype': 'F16', 'shape': [6144]}
# model.layers.8.self_attn.k_proj.biases: {'data_offsets': [1337696256, 1337794560], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.8.self_attn.k_proj.scales: {'data_offsets': [2500313088, 2500411392], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.8.self_attn.k_proj.weight: {'data_offsets': [2473955328, 2480246784], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.8.self_attn.o_proj.biases: {'data_offsets': [4391104512, 4391694336], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.8.self_attn.o_proj.scales: {'data_offsets': [2286292992, 2286882816], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.8.self_attn.o_proj.weight: {'data_offsets': [1292083200, 1329831936], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.8.self_attn.q_proj.biases: {'data_offsets': [3162058752, 3162648576], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.8.self_attn.q_proj.scales: {'data_offsets': [2292191232, 2292781056], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.8.self_attn.q_proj.weight: {'data_offsets': [2812354560, 2850103296], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.8.self_attn.v_proj.biases: {'data_offsets': [4005126144, 4005224448], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.8.self_attn.v_proj.scales: {'data_offsets': [4272746496, 4272844800], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.8.self_attn.v_proj.weight: {'data_offsets': [1331404800, 1337696256], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.9.input_layernorm.weight: {'data_offsets': [524390400, 524402688], 'dtype': 'F16', 'shape': [6144]}
# model.layers.9.mlp.down_proj.biases: {'data_offsets': [529121280, 530694144], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.9.mlp.down_proj.scales: {'data_offsets': [4003553280, 4005126144], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.9.mlp.down_proj.weight: {'data_offsets': [530792448, 631455744], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.9.mlp.gate_proj.biases: {'data_offsets': [631455744, 633028608], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.9.mlp.gate_proj.scales: {'data_offsets': [1601949696, 1603522560], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.9.mlp.gate_proj.weight: {'data_offsets': [634601472, 735264768], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.9.mlp.up_proj.biases: {'data_offsets': [524402688, 525975552], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.9.mlp.up_proj.scales: {'data_offsets': [525975552, 527548416], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.9.mlp.up_proj.weight: {'data_offsets': [881934336, 982597632], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.9.post_attention_layernorm.weight: {'data_offsets': [524378112, 524390400], 'dtype': 'F16', 'shape': [6144]}
# model.layers.9.self_attn.k_proj.biases: {'data_offsets': [2284523520, 2284621824], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.9.self_attn.k_proj.scales: {'data_offsets': [874364928, 874463232], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.9.self_attn.k_proj.weight: {'data_offsets': [3116544000, 3122835456], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.9.self_attn.o_proj.biases: {'data_offsets': [4129198080, 4129787904], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.9.self_attn.o_proj.scales: {'data_offsets': [735264768, 735854592], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.9.self_attn.o_proj.weight: {'data_offsets': [735854592, 773603328], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.9.self_attn.q_proj.biases: {'data_offsets': [880754688, 881344512], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.9.self_attn.q_proj.scales: {'data_offsets': [881344512, 881934336], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.9.self_attn.q_proj.weight: {'data_offsets': [4315508736, 4353257472], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.9.self_attn.v_proj.biases: {'data_offsets': [773603328, 773701632], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.9.self_attn.v_proj.scales: {'data_offsets': [3267047424, 3267145728], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.9.self_attn.v_proj.weight: {'data_offsets': [3367907328, 3374198784], 'dtype': 'U32', 'shape': [1024, 1536]}
#
# Header information:
# __metadata__: {'format': 'mlx'}
# model.layers.12.input_layernorm.weight: {'data_offsets': [5333495808, 5333508096], 'dtype': 'F16', 'shape': [6144]}
# model.layers.12.mlp.down_proj.biases: {'data_offsets': [5322055680, 5323628544], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.12.mlp.down_proj.scales: {'data_offsets': [5326798848, 5328371712], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.12.mlp.down_proj.weight: {'data_offsets': [1032572928, 1133236224], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.12.mlp.gate_proj.biases: {'data_offsets': [5279969280, 5281542144], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.12.mlp.gate_proj.scales: {'data_offsets': [5022806016, 5024378880], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.12.mlp.gate_proj.weight: {'data_offsets': [5177536512, 5278199808], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.12.mlp.up_proj.biases: {'data_offsets': [5325127680, 5326700544], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.12.mlp.up_proj.scales: {'data_offsets': [4011847680, 4013420544], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.12.mlp.up_proj.weight: {'data_offsets': [4537085952, 4637749248], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.12.post_attention_layernorm.weight: {'data_offsets': [1141297152, 1141309440], 'dtype': 'F16', 'shape': [6144]}
# model.layers.13.input_layernorm.weight: {'data_offsets': [5323739136, 5323751424], 'dtype': 'F16', 'shape': [6144]}
# model.layers.13.mlp.down_proj.biases: {'data_offsets': [3892101120, 3893673984], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.13.mlp.down_proj.scales: {'data_offsets': [4327305216, 4328878080], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.13.mlp.down_proj.weight: {'data_offsets': [4435832832, 4536496128], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.13.mlp.gate_proj.biases: {'data_offsets': [2166116352, 2167689216], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.13.mlp.gate_proj.scales: {'data_offsets': [1778565120, 1780137984], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.13.mlp.gate_proj.weight: {'data_offsets': [3661750272, 3762413568], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.13.mlp.up_proj.biases: {'data_offsets': [3900567552, 3902140416], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.13.mlp.up_proj.scales: {'data_offsets': [4222611456, 4224184320], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.13.mlp.up_proj.weight: {'data_offsets': [4114083840, 4214747136], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.13.post_attention_layernorm.weight: {'data_offsets': [3358654464, 3358666752], 'dtype': 'F16', 'shape': [6144]}
# model.layers.13.self_attn.k_proj.biases: {'data_offsets': [5323640832, 5323739136], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.13.self_attn.k_proj.scales: {'data_offsets': [3148972032, 3149070336], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.13.self_attn.k_proj.weight: {'data_offsets': [3884236800, 3890528256], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.13.self_attn.o_proj.biases: {'data_offsets': [4820889600, 4821479424], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.13.self_attn.o_proj.scales: {'data_offsets': [1636909056, 1637498880], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.13.self_attn.o_proj.weight: {'data_offsets': [5099876352, 5137625088], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.13.self_attn.q_proj.biases: {'data_offsets': [4536496128, 4537085952], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.13.self_attn.q_proj.scales: {'data_offsets': [5332905984, 5333495808], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.13.self_attn.q_proj.weight: {'data_offsets': [5282131968, 5319880704], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.13.self_attn.v_proj.biases: {'data_offsets': [4675497984, 4675596288], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.13.self_attn.v_proj.scales: {'data_offsets': [5279772672, 5279870976], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.13.self_attn.v_proj.weight: {'data_offsets': [4776849408, 4783140864], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.14.input_layernorm.weight: {'data_offsets': [3557339136, 3557351424], 'dtype': 'F16', 'shape': [6144]}
# model.layers.14.mlp.down_proj.biases: {'data_offsets': [3762413568, 3763986432], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.14.mlp.down_proj.scales: {'data_offsets': [3775598592, 3777171456], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers
 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.15.self_attn.q_proj.weight: {'data_offsets': [5024378880, 5062127616], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.15.self_attn.v_proj.biases: {'data_offsets': [3396415488, 3396513792], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.15.self_attn.v_proj.scales: {'data_offsets': [3358556160, 3358654464], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.15.self_attn.v_proj.weight: {'data_offsets': [3500322816, 3506614272], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.16.input_layernorm.weight: {'data_offsets': [2166104064, 2166116352], 'dtype': 'F16', 'shape': [6144]}
# model.layers.16.mlp.down_proj.biases: {'data_offsets': [3555176448, 3556749312], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.16.mlp.down_proj.scales: {'data_offsets': [4214747136, 4216320000], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.16.mlp.down_proj.weight: {'data_offsets': [1899786240, 2000449536], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.16.mlp.gate_proj.biases: {'data_offsets': [3552915456, 3554488320], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.16.mlp.gate_proj.scales: {'data_offsets': [1216831488, 1218404352], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.16.mlp.gate_proj.weight: {'data_offsets': [2268352512, 2369015808], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.16.mlp.up_proj.biases: {'data_offsets': [5320482816, 5322055680], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.16.mlp.up_proj.scales: {'data_offsets': [5331333120, 5332905984], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.16.mlp.up_proj.weight: {'data_offsets': [2167689216, 2268352512], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.16.post_attention_layernorm.weight: {'data_offsets': [2164518912, 2164531200], 'dtype': 'F16', 'shape': [6144]}
# model.layers.16.self_attn.k_proj.biases: {'data_offsets': [5323751424, 5323849728], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.16.self_attn.k_proj.scales: {'data_offsets': [5330644992, 5330743296], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.16.self_attn.k_proj.weight: {'data_offsets': [2471841792, 2478133248], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.16.self_attn.o_proj.biases: {'data_offsets': [2369015808, 2369605632], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.16.self_attn.o_proj.scales: {'data_offsets': [4675596288, 4676186112], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.16.self_attn.o_proj.weight: {'data_offsets': [2516471808, 2554220544], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.16.self_attn.q_proj.biases: {'data_offsets': [2478133248, 2478723072], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.16.self_attn.q_proj.scales: {'data_offsets': [1738358784, 1738948608], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.16.self_attn.q_proj.weight: {'data_offsets': [2554220544, 2591969280], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.16.self_attn.v_proj.biases: {'data_offsets': [3777171456, 3777269760], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.16.self_attn.v_proj.scales: {'data_offsets': [3149168640, 3149266944], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.16.self_attn.v_proj.weight: {'data_offsets': [3877933056, 3884224512], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.17.input_layernorm.weight: {'data_offsets': [1780137984, 1780150272], 'dtype': 'F16', 'shape': [6144]}
# model.layers.17.mlp.down_proj.biases: {'data_offsets': [1890349056, 1891921920], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.17.mlp.down_proj.scales: {'data_offsets': [3354624000, 3356196864], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.17.mlp.down_proj.weight: {'data_offsets': [3777269760, 3877933056], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.17.mlp.gate_proj.biases: {'data_offsets': [2000449536, 2002022400], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.17.mlp.gate_proj.scales: {'data_offsets': [2369605632, 2371178496], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.17.mlp.gate_proj.weight: {'data_offsets': [2371178496, 2471841792], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.17.mlp.up_proj.biases: {'data_offsets': [3771850752, 3773423616], 'dtype': 'F16', 'shape': [16384, 48]}
# ...
# model.layers.50.mlp.up_proj.weight: {'data_offsets': [5074010112, 5174673408], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.50.post_attention_layernorm.weight: {'data_offsets': [112472064, 112484352], 'dtype': 'F16', 'shape': [6144]}
# model.layers.50.self_attn.k_proj.biases: {'data_offsets': [1956605952, 1956704256], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.50.self_attn.k_proj.scales: {'data_offsets': [319119360, 319217664], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.50.self_attn.k_proj.weight: {'data_offsets': [848830464, 855121920], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.50.self_attn.o_proj.biases: {'data_offsets': [5330780160, 5331369984], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.50.self_attn.o_proj.scales: {'data_offsets': [1108180992, 1108770816], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.50.self_attn.o_proj.weight: {'data_offsets': [4233572352, 4271321088], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.50.self_attn.q_proj.biases: {'data_offsets': [1593532416, 1594122240], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.50.self_attn.q_proj.scales: {'data_offsets': [1680347136, 1680936960], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.50.self_attn.q_proj.weight: {'data_offsets': [5181554688, 5219303424], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.50.self_attn.v_proj.biases: {'data_offsets': [4224921600, 4225019904], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.50.self_attn.v_proj.scales: {'data_offsets': [3585613824, 3585712128], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.50.self_attn.v_proj.weight: {'data_offsets': [1950314496, 1956605952], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.51.input_layernorm.weight: {'data_offsets': [0, 12288], 'dtype': 'F16', 'shape': [6144]}
# model.layers.51.mlp.down_proj.biases: {'data_offsets': [1585152, 3158016], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.51.mlp.down_proj.scales: {'data_offsets': [216293376, 217866240], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.51.mlp.down_proj.weight: {'data_offsets': [4472647680, 4573310976], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.51.mlp.gate_proj.biases: {'data_offsets': [2307760128, 2309332992], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.51.mlp.gate_proj.scales: {'data_offsets': [3158016, 4730880], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.51.mlp.gate_proj.weight: {'data_offsets': [4730880, 105394176], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.51.mlp.up_proj.biases: {'data_offsets': [12288, 1585152], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.51.mlp.up_proj.scales: {'data_offsets': [2838171648, 2839744512], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.51.mlp.up_proj.weight: {'data_offsets': [4868837376, 4969500672], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.51.post_attention_layernorm.weight: {'data_offsets': [1592930304, 1592942592], 'dtype': 'F16', 'shape': [6144]}
# model.layers.51.self_attn.k_proj.biases: {'data_offsets': [105394176, 105492480], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.51.self_attn.k_proj.scales: {'data_offsets': [105492480, 105590784], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.51.self_attn.k_proj.weight: {'data_offsets': [105590784, 111882240], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.51.self_attn.o_proj.biases: {'data_offsets': [217866240, 218456064], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.51.self_attn.o_proj.scales: {'data_offsets': [2197745664, 2198335488], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.51.self_attn.o_proj.weight: {'data_offsets': [2956148736, 2993897472], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.51.self_attn.q_proj.biases: {'data_offsets': [111882240, 112472064], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.51.self_attn.q_proj.scales: {'data_offsets': [2993897472, 2994487296], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.51.self_attn.q_proj.weight: {'data_offsets': [2651664384, 2689413120], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.51.self_attn.v_proj.biases: {'data_offsets': [323960832, 324059136], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.51.self_attn.v_proj.scales: {'data_offsets': [4684001280, 4684099584], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.51.self_attn.v_proj.weight: {'data_offsets': [2210918400, 2217209856], 'dtype': 'U32', 'shape': [1024, 1536]}
#
# Header information:
# __metadata__: {'format': 'mlx'}
# lm_head.biases: {'data_offsets': [0, 3072000], 'dtype': 'F16', 'shape': [32000, 48]}
# lm_head.scales: {'data_offsets': [861880320, 864952320], 'dtype': 'F16', 'shape': [32000, 48]}
# lm_head.weight: {'data_offsets': [3072000, 199680000], 'dtype': 'U32', 'shape': [32000, 1536]}
# model.layers.52.input_layernorm.weight: {'data_offsets': [1156288512, 1156300800], 'dtype': 'F16', 'shape': [6144]}
# model.layers.52.mlp.down_proj.biases: {'data_offsets': [1713696768, 1715269632], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.52.mlp.down_proj.scales: {'data_offsets': [1772482560, 1774055424], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.52.mlp.down_proj.weight: {'data_offsets': [1361166336, 1461829632], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.52.mlp.gate_proj.biases: {'data_offsets': [1468121088, 1469693952], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.52.mlp.gate_proj.scales: {'data_offsets': [1710931968, 1712504832], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.52.mlp.gate_proj.weight: {'data_offsets': [1260503040, 1361166336], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.52.mlp.up_proj.biases: {'data_offsets': [1469693952, 1471266816], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.52.mlp.up_proj.scales: {'data_offsets': [1770909696, 1772482560], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.52.mlp.up_proj.weight: {'data_offsets': [1158660096, 1259323392], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.52.post_attention_layernorm.weight: {'data_offsets': [920911872, 920924160], 'dtype': 'F16', 'shape': [6144]}
# model.layers.52.self_attn.k_proj.biases: {'data_offsets': [1716940800, 1717039104], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.52.self_attn.k_proj.scales: {'data_offsets': [922521600, 922619904], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.52.self_attn.k_proj.weight: {'data_offsets': [1756164096, 1762455552], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.52.self_attn.o_proj.biases: {'data_offsets': [920322048, 920911872], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.52.self_attn.o_proj.scales: {'data_offsets': [1259913216, 1260503040], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.52.self_attn.o_proj.weight: {'data_offsets': [1717235712, 1754984448], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.52.self_attn.q_proj.biases: {'data_offsets': [1754984448, 1755574272], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.52.self_attn.q_proj.scales: {'data_offsets': [1770319872, 1770909696], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.52.self_attn.q_proj.weight: {'data_offsets': [1774153728, 1811902464], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.52.self_attn.v_proj.biases: {'data_offsets': [1774055424, 1774153728], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.52.self_attn.v_proj.scales: {'data_offsets': [1715269632, 1715367936], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.52.self_attn.v_proj.weight: {'data_offsets': [1762455552, 1768747008], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.53.input_layernorm.weight: {'data_offsets': [920309760, 920322048], 'dtype': 'F16', 'shape': [6144]}
# model.layers.53.mlp.down_proj.biases: {'data_offsets': [922619904, 924192768], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.53.mlp.down_proj.scales: {'data_offsets': [926355456, 927928320], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.53.mlp.down_proj.weight: {'data_offsets': [1509015552, 1609678848], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.53.mlp.gate_proj.biases: {'data_offsets': [1715367936, 1716940800], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.53.mlp.gate_proj.scales: {'data_offsets': [927928320, 929501184], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.53.mlp.gate_proj.weight: {'data_offsets': [973639680, 1074302976], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.53.mlp.up_proj.biases: {'data_offsets': [1157087232, 1158660096], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.53.mlp.up_proj.scales: {'data_offsets': [920948736, 922521600], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.53.mlp.up_proj.weight: {'data_offsets': [1610268672, 1710931968], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.53.post_attention_layernorm.weight: {'data_offsets': [920924160, 920936448], 'dtype': 'F16', 'shape': [6144]}
# model.layers.53.self_attn.k_proj.biases: {'data_offsets': [1112051712, 1112150016], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.53.self_attn.k_proj.scales: {'data_offsets': [1156300800, 1156399104], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.53.self_attn.k_proj.weight: {'data_offsets': [967348224, 973639680], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.53.self_attn.o_proj.biases: {'data_offsets': [1609678848, 1610268672], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.53.self_attn.o_proj.scales: {'data_offsets': [1259323392, 1259913216], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.53.self_attn.o_proj.weight: {'data_offsets': [929501184, 967249920], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.53.self_attn.q_proj.biases: {'data_offsets': [1713094656, 1713684480], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.53.self_attn.q_proj.scales: {'data_offsets': [1755574272, 1756164096], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.53.self_attn.q_proj.weight: {'data_offsets': [1074302976, 1112051712], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.53.self_attn.v_proj.biases: {'data_offsets': [1118441472, 1118539776], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.53.self_attn.v_proj.scales: {'data_offsets': [967249920, 967348224], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.53.self_attn.v_proj.weight: {'data_offsets': [1461829632, 1468121088], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.54.input_layernorm.weight: {'data_offsets': [864952320, 864964608], 'dtype': 'F16', 'shape': [6144]}
# model.layers.54.mlp.down_proj.biases: {'data_offsets': [654151680, 655724544], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.54.mlp.down_proj.scales: {'data_offsets': [657297408, 658870272], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.54.mlp.down_proj.weight: {'data_offsets': [658870272, 759533568], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.54.mlp.gate_proj.biases: {'data_offsets': [918736896, 920309760], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.54.mlp.gate_proj.scales: {'data_offsets': [759533568, 761106432], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.54.mlp.gate_proj.weight: {'data_offsets': [761106432, 861769728], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.54.mlp.up_proj.biases: {'data_offsets': [1768747008, 1770319872], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.54.mlp.up_proj.scales: {'data_offsets': [924782592, 926355456], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.54.mlp.up_proj.weight: {'data_offsets': [553488384, 654151680], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.54.post_attention_layernorm.weight: {'data_offsets': [553476096, 553488384], 'dtype': 'F16', 'shape': [6144]}
# model.layers.54.self_attn.k_proj.biases: {'data_offsets': [1717137408, 1717235712], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.54.self_attn.k_proj.scales: {'data_offsets': [871845888, 871944192], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.54.self_attn.k_proj.weight: {'data_offsets': [871944192, 878235648], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.54.self_attn.o_proj.biases: {'data_offsets': [871256064, 871845888], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.54.self_attn.o_proj.scales: {'data_offsets': [1156399104, 1156988928], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.54.self_attn.o_proj.weight: {'data_offsets': [1118539776, 1156288512], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.54.self_attn.q_proj.biases: {'data_offsets': [879808512, 880398336], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.54.self_attn.q_proj.scales: {'data_offsets': [880398336, 880988160], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.54.self_attn.q_proj.weight: {'data_offsets': [880988160, 918736896], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.54.self_attn.v_proj.biases: {'data_offsets': [1156988928, 1157087232], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.54.self_attn.v_proj.scales: {'data_offsets': [861782016, 861880320], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.54.self_attn.v_proj.weight: {'data_offsets': [864964608, 871256064], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.55.input_layernorm.weight: {'data_offsets': [920936448, 920948736], 'dtype': 'F16', 'shape': [6144]}
# model.layers.55.mlp.down_proj.biases: {'data_offsets': [404152320, 405725184], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.55.mlp.down_proj.scales: {'data_offsets': [878235648, 879808512], 'dtype': 'F16', 'shape': [6144, 128]}
# model.layers.55.mlp.down_proj.weight: {'data_offsets': [445833216, 546496512], 'dtype': 'U32', 'shape': [6144, 4096]}
# model.layers.55.mlp.gate_proj.biases: {'data_offsets': [444063744, 445636608], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.55.mlp.gate_proj.scales: {'data_offsets': [655724544, 657297408], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.55.mlp.gate_proj.weight: {'data_offsets': [303489024, 404152320], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.55.mlp.up_proj.biases: {'data_offsets': [199680000, 201252864], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.55.mlp.up_proj.scales: {'data_offsets': [201252864, 202825728], 'dtype': 'F16', 'shape': [16384, 48]}
# model.layers.55.mlp.up_proj.weight: {'data_offsets': [202825728, 303489024], 'dtype': 'U32', 'shape': [16384, 1536]}
# model.layers.55.post_attention_layernorm.weight: {'data_offsets': [861769728, 861782016], 'dtype': 'F16', 'shape': [6144]}
# model.layers.55.self_attn.k_proj.biases: {'data_offsets': [1717039104, 1717137408], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.55.self_attn.k_proj.scales: {'data_offsets': [553377792, 553476096], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.55.self_attn.k_proj.weight: {'data_offsets': [1112150016, 1118441472], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.layers.55.self_attn.o_proj.biases: {'data_offsets': [924192768, 924782592], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.55.self_attn.o_proj.scales: {'data_offsets': [405725184, 406315008], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.55.self_attn.o_proj.weight: {'data_offsets': [406315008, 444063744], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.55.self_attn.q_proj.biases: {'data_offsets': [1712504832, 1713094656], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.55.self_attn.q_proj.scales: {'data_offsets': [552787968, 553377792], 'dtype': 'F16', 'shape': [6144, 48]}
# model.layers.55.self_attn.q_proj.weight: {'data_offsets': [1471266816, 1509015552], 'dtype': 'U32', 'shape': [6144, 1536]}
# model.layers.55.self_attn.v_proj.biases: {'data_offsets': [445636608, 445734912], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.55.self_attn.v_proj.scales: {'data_offsets': [445734912, 445833216], 'dtype': 'F16', 'shape': [1024, 48]}
# model.layers.55.self_attn.v_proj.weight: {'data_offsets': [546496512, 552787968], 'dtype': 'U32', 'shape': [1024, 1536]}
# model.norm.weight: {'data_offsets': [1713684480, 1713696768], 'dtype': 'F16', 'shape': [6144]}
#
# Total across all files:
# Total layers: 0
# Total parameters: array(1756854272, dtype=int32)

# %% [markdown]
# ## Converts a chat dataset of system/user/assistant to the format mlx-lm requires for chat conversations, then splits to train, test, valid jsonl files

# %%
import json
import random

# Read the system.jsonl file
with open("./data/system.jsonl", "r") as file:
    data = [json.loads(line) for line in file]

# Convert the format
converted_data = []
for item in data:
    messages = [{"role": "system", "content": item["conversations"][0]["value"]}]
    for message in item["conversations"][1:]:
        role = "user" if message["from"] == "human" else "assistant"
        messages.append({"role": role, "content": message["value"]})
    converted_item = {"messages": messages}
    converted_data.append(converted_item)

# Shuffle the data
random.shuffle(converted_data)

# Calculate the split sizes
total_size = len(converted_data)
train_size = int(total_size * 0.8)
valid_size = int(total_size * 0.1)
test_size = total_size - train_size - valid_size

# Split the data into train, test, and valid sets
train_data = converted_data[:train_size]
valid_data = converted_data[train_size : train_size + valid_size]
test_data = converted_data[train_size + valid_size :]

# Save the train data as train.jsonl
with open("./traindata/train.jsonl", "w") as file:
    for item in train_data:
        file.write(json.dumps(item) + "\n")

# Save the test data as test.jsonl
with open("./traindata/test.jsonl", "w") as file:
    for item in test_data:
        file.write(json.dumps(item) + "\n")

# Save the valid data as valid.jsonl
with open("./traindata/valid.jsonl", "w") as file:
    for item in valid_data:
        file.write(json.dumps(item) + "\n")
